# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
# X_train load the training set
# y_train load the training labels

# X_val load the validation set
# y_val load the validation labels

# X_test load the test set
# Y_test load the test labels


X_train, y_train = shuffle(X_train, y_train, random_state=42)
X_val, y_val = shuffle(X_val, y_val, random_state=42)
X_train_val = np.concatenate((X_train,X_val), axis=0)
y_train_val = np.concatenate((y_train,_y_val), axis=0)


names = ['3-KNN', '5-KNN', 'LDA', 'LogisticRegressionRidge', 'LogisticRegressionLasso', 'QDA','SVM']


classifiers = [KNeighborsClassifier(n_neighbors=3), KNeighborsClassifier(n_neighbors=5), LinearDiscriminantAnalysis(), LogisticRegression(penalty='l2'),LogisticRegression(penalty='l1',tol=0.01, random_state=0, solver='liblinear'), QuadraticDiscriminantAnalysis(), SVC()]

# Training 
ca_train_score = {}  # Classification accuracy

# Validation
ca_val_score = {} 

#test
ca_test_score = {}

for name, clf in zip(names, classifiers):
    print(name)
    scaler = MinMaxScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    validation_set = scaler.transform(validation_set)
        
        
    clf.fit(X_train, y_train)
    ca_train_score[name] = clf.score(X_train, y_train)
    ca_val_score[name] = clf.score( validation_set , validation_labels)
    

    scaler = MinMaxScaler()
    scaler.fit(X_train_val)
    X_train_val = scaler.transform(X_train_val)
    test_set = scaler.transform(test_set)
        
    clf.fit(X_train_val,y_train_val)
    ca_test_score[name] = clf.score(test_set, test_labels)
    fig, ax = plt.subplots(figsize=(40, 40))
    
    plot_confusion_matrix(clf, test_set, test_labels, ax=ax)
    
    filename = r'C:\...directory for saving the confusion matrix' + name + '.png'
    
    fig.savefig(filename)
    plt.show()

print('Classification performance on training,validation and test sets: \n')
print("{0:<20s}   {1:-^10s}   {2:-^10s}   {3:-^10s}".format('','Training','Validation',  'Test'))
print("{0:<20s}{1:>13s}{2:>13s}{3:>13s}".format(
    'Method', 'Accuracy\u2191',
    'Accuracy\u2191','Accuracy\u2191'))
print("-"*(20+4*13))
for clf in names:
    print ("{method:<20s}{train_accuracy:>13.3f}{val_accuracy:>13.3f}{test_accuracy:>13.3f}".format(method=clf, train_accuracy=ca_train_score[clf],val_accuracy=ca_val_score[clf],test_accuracy=ca_test_score[clf]))
